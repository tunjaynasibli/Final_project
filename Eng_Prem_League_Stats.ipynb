# %%
import pandas as pd

# %%
data = pd.read_csv("E1.csv")

# %%
data
# Out:
#     Div        Date   Time          HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  12/09/2020  12:30            Fulham         Arsenal     0     3   A
# 1    E0  12/09/2020  15:00    Crystal Palace     Southampton     1     0   H
# 2    E0  12/09/2020  17:30         Liverpool           Leeds     4     3   H
# 3    E0  12/09/2020  20:00          West Ham       Newcastle     0     2   A
# 4    E0  13/09/2020  14:00         West Brom       Leicester     0     3   A
# ..   ..         ...    ...               ...             ...   ...   ...  ..
# 375  E0  23/05/2021  16:00         Liverpool  Crystal Palace     2     0   H
# 376  E0  23/05/2021  16:00          Man City         Everton     5     0   H
# 377  E0  23/05/2021  16:00  Sheffield United         Burnley     1     0   H
# 378  E0  23/05/2021  16:00          West Ham     Southampton     3     0   H
# 379  E0  23/05/2021  16:00            Wolves      Man United     1     2   A
#
# ...

# %%
# http://football-data.co.uk/notes.txt

# %%
column_list = list(data.columns)

# %%
column_list
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'Referee',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
newlist_columns = ['Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee',
                  'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'MaxH', 'MaxD', 'MaxA',
                  'Max>2.5','Max<2.5',  ]

# %%
removed_list = data.drop(newlist_columns, axis=1)
removed_list
# Out:
#     Div  B365H  B365D  B365A   BWH   BWD    BWA   IWH   IWD    IWA  ...  \
# 0    E0   6.00   4.33   1.53  5.50  4.25   1.57  6.00  3.90   1.57  ...
# 1    E0   3.10   3.25   2.37  3.00  3.20   2.45  3.15  2.95   2.40  ...
# 2    E0   1.28   6.00   9.50  1.26  6.25  10.50  1.35  5.00   8.50  ...
# 3    E0   2.15   3.40   3.40  2.15  3.40   3.40  2.15  3.15   3.40  ...
# 4    E0   3.80   3.60   1.95  3.70  3.60   2.00  3.85  3.20   2.00  ...
# ..   ..    ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 375  E0   1.14   8.50  15.00  1.16  8.00  16.50  1.15  8.25  16.00  ...
# 376  E0   1.44   5.00   6.50  1.44  5.00   6.50  1.47  4.90   6.00  ...
# 377  E0   2.80   3.60   2.40  2.80  3.60   2.40  2.85  3.60   2.40  ...
# 378  E0   1.65   4.00   5.00  1.72  4.00   4.60  1.70  4.10   4.60  ...
# 379  E0   2.50   3.50   2.70  2.50  3.60   2.70  2.55  3.60   2.65  ...
#
#      AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# ...

# %%
data.drop(removed_list, axis=1, inplace=True)
data
# Out:
#            Date   Time          HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    12/09/2020  12:30            Fulham         Arsenal     0     3   A
# 1    12/09/2020  15:00    Crystal Palace     Southampton     1     0   H
# 2    12/09/2020  17:30         Liverpool           Leeds     4     3   H
# 3    12/09/2020  20:00          West Ham       Newcastle     0     2   A
# 4    13/09/2020  14:00         West Brom       Leicester     0     3   A
# ..          ...    ...               ...             ...   ...   ...  ..
# 375  23/05/2021  16:00         Liverpool  Crystal Palace     2     0   H
# 376  23/05/2021  16:00          Man City         Everton     5     0   H
# 377  23/05/2021  16:00  Sheffield United         Burnley     1     0   H
# 378  23/05/2021  16:00          West Ham     Southampton     3     0   H
# 379  23/05/2021  16:00            Wolves      Man United     1     2   A
#
#      HTHG  HTAG HTR  ... AC  HY  AY  HR  AR  MaxH  MaxD   MaxA  Max>2.5  \
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'MaxH', 'MaxD', 'MaxA', 'Max>2.5',
#        'Max<2.5'],
#       dtype='object')

# %%
hide_list= ["Date", 'Time', 'Referee', 'MaxH', 'MaxD', 'MaxA', 'Max>2.5', 'Max<2.5']

# %%
short_data = data.drop(hide_list, axis=1 )

# %%
short_data
# Out:
#              HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  \
# 0              Fulham         Arsenal     0     3   A     0     1   A   5  13
# 1      Crystal Palace     Southampton     1     0   H     1     0   H   5   9
# 2           Liverpool           Leeds     4     3   H     3     2   H  22   6
# 3            West Ham       Newcastle     0     2   A     0     0   D  15  15
# 4           West Brom       Leicester     0     3   A     0     0   D   7  13
# ..                ...             ...   ...   ...  ..   ...   ...  ..  ..  ..
# 375         Liverpool  Crystal Palace     2     0   H     1     0   H  19   5
# 376          Man City         Everton     5     0   H     2     0   H  21   8
# 377  Sheffield United         Burnley     1     0   H     1     0   H  12  10
# 378          West Ham     Southampton     3     0   H     2     0   H  14  17
# 379            Wolves      Man United     1     2   A     1     2   A  14   9
#
# ...

# %%
short_data[short_data["HomeTeam"] == "Arsenal"]
# Out:
#     HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  HST  \
# 11   Arsenal          West Ham     2     1   H     1     1   D   7  14    3
# 34   Arsenal  Sheffield United     2     1   H     0     0   D   6   6    5
# 55   Arsenal         Leicester     0     1   A     0     0   D  12   6    4
# 77   Arsenal       Aston Villa     0     3   A     0     1   A  13  15    2
# 95   Arsenal            Wolves     1     2   A     1     2   A  13  11    2
# 115  Arsenal           Burnley     0     1   A     0     0   D  18  10    6
# 119  Arsenal       Southampton     1     1   D     0     1   A   9  13    4
# 140  Arsenal           Chelsea     3     1   H     2     0   H  15  19    7
# 169  Arsenal    Crystal Palace     0     0   D     0     0   D  11  12    4
# 178  Arsenal         Newcastle     3     0   H     0     0   D  20   4    6
# 199  Arsenal        Man United     0     0   D     0     0   D  17  14    3
# ...
